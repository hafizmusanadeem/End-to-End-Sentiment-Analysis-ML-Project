# %%
print("hello")
# Out:
# Running cells with 'myenv (Python 3.10.19)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n myenv ipykernel --update-deps --force-reinstall'
